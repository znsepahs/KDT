# %%
#%pip install koreanize_matplotlib
# Out:
# Collecting koreanize_matplotlibNote: you may need to restart the kernel to use updated packages.
#
#   Using cached koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from koreanize_matplotlib) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from matplotlib->koreanize_matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->koreanize_matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\lg\anaconda3\envs\torch_38\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)
# Using cached koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
import torch
import torch.nn as nn 
from torchvision import models, datasets, transforms
from torchvision.models import VGG19_BN_Weights
from torchvision.models import ResNet50_Weights
import torchvision.transforms.functional as TF
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import koreanize_matplotlib
from torch.utils.data import random_split
from sklearn.model_selection import train_test_split
import cv2
import os
import sys
sys.path.append(r'C:\WorkSpace\KDT\MyModule')
from DLModule import *

# %%
# 이미지 전처리(transform) 정의
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 이미지 크기 조정
    transforms.ToTensor(),          # 텐서로 변환
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # ImageNet 정규화 값
])

# %%
# 이미지 증강하기

# 원본 이미지 경로
ROOT_PATH = r'C:\WorkSpace\LocalData\pj_14_final\data_a'

# # 증강된 이미지 저장 경로
# SAVE_PATH_A = r'D:\yunho\pj_14_final\data_a'

# ImageFolder 사용
DS = datasets.ImageFolder(root=ROOT_PATH, transform=transform)

originDS = datasets.ImageFolder(root=ROOT_PATH)

# for i in range(len(originDS)):
#     for j in [0, 90, 180, 270]:
#         class_name = DS.classes[DS[i][1]]
#         FILE_PATH = os.path.join(SAVE_PATH_A, class_name, f'img_index{i}_{j}.jpg')
#         FILE_PATH2 = os.path.join(SAVE_PATH_A, class_name, f'flip_img_index{i}_{j}.jpg')
#         rotate_img = originDS[i][0].rotate(j, expand=True)
#         flipped_img = rotate_img.transpose(Image.FLIP_LEFT_RIGHT)
#         rotate_img.save(FILE_PATH)
#         flipped_img.save(FILE_PATH2)

# 데이터 증강 후에 반복문 주석처리하고 ROOT_PATH를 증강한 이미지 저장된 위치로 변경 => 데이터 갯수 확인 후 학습 시작

# %%
# DataLoader
DL = DataLoader(DS, batch_size = 32, shuffle=True)

print(f'데이터 클래스 : {DS.classes}\n데이터 개수 : {len(DL.dataset)}개')
# Out:
# 데이터 클래스 : ['fire', 'nofire', 'smoke', 'smokefire']
# 데이터 개수 : 41656개

# %%
file_path = [i[0] for i in DS.imgs]
labels = [i[1] for i in DS.imgs]

# %%
train_path, test_path, train_labels, test_labels = train_test_split(file_path, labels, stratify=labels,
                                                                    random_state = 42, train_size = 0.8)
train_path, valid_path, train_labels, valid_labels = train_test_split(train_path, train_labels,
                                                                      stratify=train_labels,
                                                                      random_state = 42, train_size = 0.8)

# %%
class ImagePathDataset(Dataset):
    def __init__(self, file_paths, labels, transform=None):
        super().__init__()
        self.file_paths = file_paths
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        img_path = self.file_paths[idx]
        image = Image.open(img_path).convert("RGB")

        if self.transform != None:
            image = self.transform(image)

        # 레이블 불러오기
        label = self.labels[idx]

        return image, label

# %%
trainDS = ImagePathDataset(train_path, train_labels, transform=transform)
validDS = ImagePathDataset(valid_path, valid_labels, transform=transform)
testDS = ImagePathDataset(test_path, test_labels, transform=transform)

trainDL = DataLoader(trainDS, batch_size = 32)
validDL = DataLoader(validDS, batch_size = 32)
testDL = DataLoader(testDS, batch_size = 32)

# %%
name_dict = {0 : 'fire', 1 : 'nofire', 2: 'smoke' , 3 : 'smokefire'}

INDEX = 15

a = DL.dataset[INDEX][0].permute(1,2,0)
plt.axis('off')
plt.title(name_dict[DL.dataset[INDEX][1]])
plt.imshow(a)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# GPU 사용 가능 여부 확인 
if torch.cuda.is_available():
    print('GPU')
    device = torch.device("cuda")
else:
    print('CPU')
    device = torch.device("cpu")
# Out:
# CPU

# %% [markdown]
# > > > 전이학습 모델 - Resnet50

# %%
# 전이학습 모델 ResNet (weight 사용)
model = models.resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)

# 합성곱층 가중치 고정
for param in model.parameters():
    param.requires_grad = False

# 전결합층 가중치 변경하도록 설정
for param in model.fc.parameters():
    param.requires_grad = True

# %%
# 마지막 레이어 (full connected layer) 교체
num_features = model.fc.in_features # 2048
model.fc = nn.Linear(num_features, 4)

# 옵티마이저를 모델 파라미터에 대해 초기화
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
trainDL.dataset[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
EPOCH = 100
SAVE_PATH = r'D:\yunho\pj_14_final\resnet_model'

result=training(trainDL, validDL, model,
                 model_type = 'multiclass', optimizer = optimizer,
                 epoch = EPOCH, endurance_cnt = 5, view_epoch = 1,
                 num_classes = 4, SAVE_PATH = SAVE_PATH)
# Out:
# [EPOCH] : [1] 모델을 저장합니다.
# [Loss : 1/100] Train : 0.4473, Test : 0.3352
# [Score  : 1/100] Train : 0.8323, Test : 0.8726
# [EPOCH] : [2] 모델을 저장합니다.
# [Loss : 2/100] Train : 0.2777, Test : 0.3086
# [Score  : 2/100] Train : 0.8957, Test : 0.8798
# [EPOCH] : [3] 모델을 저장합니다.
# [Loss : 3/100] Train : 0.2438, Test : 0.2980
# [Score  : 3/100] Train : 0.9076, Test : 0.8826
# [EPOCH] : [4] 모델을 저장합니다.
# [Loss : 4/100] Train : 0.2237, Test : 0.2921
# [Score  : 4/100] Train : 0.9155, Test : 0.8856
# [EPOCH] : [5] 모델을 저장합니다.
# [Loss : 5/100] Train : 0.2088, Test : 0.2878
# [Score  : 5/100] Train : 0.9217, Test : 0.8862
# [EPOCH] : [6] 모델을 저장합니다.
# [Loss : 6/100] Train : 0.1968, Test : 0.2840
# [Score  : 6/100] Train : 0.9261, Test : 0.8882
# [EPOCH] : [7] 모델을 저장합니다.
# [Loss : 7/100] Train : 0.1868, Test : 0.2806
# [Score  : 7/100] Train : 0.9302, Test : 0.8910
# [EPOCH] : [8] 모델을 저장합니다.
# [Loss : 8/100] Train : 0.1781, Test : 0.2775
# [Score  : 8/100] Train : 0.9336, Test : 0.8949
# [EPOCH] : [9] 모델을 저장합니다.
# [Loss : 9/100] Train : 0.1706, Test : 0.2747
# [Score  : 9/100] Train : 0.9365, Test : 0.8959
# [EPOCH] : [10] 모델을 저장합니다.
# [Loss : 10/100] Train : 0.1639, Test : 0.2722
# [Score  : 10/100] Train : 0.9387, Test : 0.8971
# [EPOCH] : [11] 모델을 저장합니다.
# [Loss : 11/100] Train : 0.1579, Test : 0.2699
# [Score  : 11/100] Train : 0.9407, Test : 0.8979
# [EPOCH] : [12] 모델을 저장합니다.
# [Loss : 12/100] Train : 0.1525, Test : 0.2677
# [Score  : 12/100] Train : 0.9429, Test : 0.9000
# [EPOCH] : [13] 모델을 저장합니다.
# [Loss : 13/100] Train : 0.1475, Test : 0.2657
# [Score  : 13/100] Train : 0.9453, Test : 0.9007
# [EPOCH] : [14] 모델을 저장합니다.
# [Loss : 14/100] Train : 0.1430, Test : 0.2636
# [Score  : 14/100] Train : 0.9466, Test : 0.9012
# [EPOCH] : [15] 모델을 저장합니다.
# [Loss : 15/100] Train : 0.1388, Test : 0.2616
# [Score  : 15/100] Train : 0.9481, Test : 0.9012
# [EPOCH] : [16] 모델을 저장합니다.
# [Loss : 16/100] Train : 0.1349, Test : 0.2597
# [Score  : 16/100] Train : 0.9501, Test : 0.9028
# [EPOCH] : [17] 모델을 저장합니다.
# [Loss : 17/100] Train : 0.1313, Test : 0.2577
# [Score  : 17/100] Train : 0.9515, Test : 0.9048
# [EPOCH] : [18] 모델을 저장합니다.
# [Loss : 18/100] Train : 0.1280, Test : 0.2557
# [Score  : 18/100] Train : 0.9526, Test : 0.9064
# [EPOCH] : [19] 모델을 저장합니다.
# [Loss : 19/100] Train : 0.1248, Test : 0.2536
# [Score  : 19/100] Train : 0.9540, Test : 0.9076
# [EPOCH] : [20] 모델을 저장합니다.
# [Loss : 20/100] Train : 0.1219, Test : 0.2515
# [Score  : 20/100] Train : 0.9553, Test : 0.9092
# [EPOCH] : [21] 모델을 저장합니다.
# [Loss : 21/100] Train : 0.1191, Test : 0.2494
# [Score  : 21/100] Train : 0.9560, Test : 0.9106
# [EPOCH] : [22] 모델을 저장합니다.
# [Loss : 22/100] Train : 0.1165, Test : 0.2473
# [Score  : 22/100] Train : 0.9571, Test : 0.9118
# [EPOCH] : [23] 모델을 저장합니다.
# [Loss : 23/100] Train : 0.1141, Test : 0.2451
# [Score  : 23/100] Train : 0.9584, Test : 0.9134
# [EPOCH] : [24] 모델을 저장합니다.
# [Loss : 24/100] Train : 0.1117, Test : 0.2428
# [Score  : 24/100] Train : 0.9592, Test : 0.9146
# [EPOCH] : [25] 모델을 저장합니다.
# [Loss : 25/100] Train : 0.1095, Test : 0.2405
# [Score  : 25/100] Train : 0.9602, Test : 0.9158
# [EPOCH] : [26] 모델을 저장합니다.
# [Loss : 26/100] Train : 0.1074, Test : 0.2381
# [Score  : 26/100] Train : 0.9610, Test : 0.9172
# [EPOCH] : [27] 모델을 저장합니다.
# [Loss : 27/100] Train : 0.1054, Test : 0.2357
# [Score  : 27/100] Train : 0.9619, Test : 0.9185
# [EPOCH] : [28] 모델을 저장합니다.
# [Loss : 28/100] Train : 0.1035, Test : 0.2333
# [Score  : 28/100] Train : 0.9627, Test : 0.9188
# [EPOCH] : [29] 모델을 저장합니다.
# [Loss : 29/100] Train : 0.1017, Test : 0.2308
# [Score  : 29/100] Train : 0.9637, Test : 0.9196
# [EPOCH] : [30] 모델을 저장합니다.
# [Loss : 30/100] Train : 0.0999, Test : 0.2283
# [Score  : 30/100] Train : 0.9647, Test : 0.9208
# [EPOCH] : [31] 모델을 저장합니다.
# [Loss : 31/100] Train : 0.0982, Test : 0.2259
# [Score  : 31/100] Train : 0.9653, Test : 0.9217
# [EPOCH] : [32] 모델을 저장합니다.
# [Loss : 32/100] Train : 0.0966, Test : 0.2235
# [Score  : 32/100] Train : 0.9660, Test : 0.9227
# [EPOCH] : [33] 모델을 저장합니다.
# [Loss : 33/100] Train : 0.0951, Test : 0.2210
# [Score  : 33/100] Train : 0.9664, Test : 0.9230
# [EPOCH] : [34] 모델을 저장합니다.
# [Loss : 34/100] Train : 0.0936, Test : 0.2187
# [Score  : 34/100] Train : 0.9672, Test : 0.9236
# [EPOCH] : [35] 모델을 저장합니다.
# [Loss : 35/100] Train : 0.0921, Test : 0.2163
# [Score  : 35/100] Train : 0.9679, Test : 0.9245
# [EPOCH] : [36] 모델을 저장합니다.
# [Loss : 36/100] Train : 0.0908, Test : 0.2140
# [Score  : 36/100] Train : 0.9687, Test : 0.9251
# [EPOCH] : [37] 모델을 저장합니다.
# [Loss : 37/100] Train : 0.0894, Test : 0.2118
# [Score  : 37/100] Train : 0.9689, Test : 0.9255
# [EPOCH] : [38] 모델을 저장합니다.
# [Loss : 38/100] Train : 0.0882, Test : 0.2096
# [Score  : 38/100] Train : 0.9692, Test : 0.9267
# [EPOCH] : [39] 모델을 저장합니다.
# [Loss : 39/100] Train : 0.0869, Test : 0.2075
# [Score  : 39/100] Train : 0.9696, Test : 0.9275
# [EPOCH] : [40] 모델을 저장합니다.
# [Loss : 40/100] Train : 0.0857, Test : 0.2054
# [Score  : 40/100] Train : 0.9699, Test : 0.9288
# [EPOCH] : [41] 모델을 저장합니다.
# [Loss : 41/100] Train : 0.0846, Test : 0.2034
# [Score  : 41/100] Train : 0.9703, Test : 0.9294
# [EPOCH] : [42] 모델을 저장합니다.
# [Loss : 42/100] Train : 0.0835, Test : 0.2014
# [Score  : 42/100] Train : 0.9708, Test : 0.9302
# [EPOCH] : [43] 모델을 저장합니다.
# [Loss : 43/100] Train : 0.0824, Test : 0.1995
# [Score  : 43/100] Train : 0.9710, Test : 0.9306
# [EPOCH] : [44] 모델을 저장합니다.
# [Loss : 44/100] Train : 0.0813, Test : 0.1976
# [Score  : 44/100] Train : 0.9714, Test : 0.9308
# [EPOCH] : [45] 모델을 저장합니다.
# [Loss : 45/100] Train : 0.0803, Test : 0.1958
# [Score  : 45/100] Train : 0.9717, Test : 0.9318
# [EPOCH] : [46] 모델을 저장합니다.
# [Loss : 46/100] Train : 0.0793, Test : 0.1941
# [Score  : 46/100] Train : 0.9724, Test : 0.9324
# [EPOCH] : [47] 모델을 저장합니다.
# [Loss : 47/100] Train : 0.0784, Test : 0.1924
# [Score  : 47/100] Train : 0.9728, Test : 0.9327
# [EPOCH] : [48] 모델을 저장합니다.
# [Loss : 48/100] Train : 0.0774, Test : 0.1908
# [Score  : 48/100] Train : 0.9731, Test : 0.9335
# [EPOCH] : [49] 모델을 저장합니다.
# [Loss : 49/100] Train : 0.0765, Test : 0.1892
# [Score  : 49/100] Train : 0.9735, Test : 0.9335
# [EPOCH] : [50] 모델을 저장합니다.
# [Loss : 50/100] Train : 0.0756, Test : 0.1876
# [Score  : 50/100] Train : 0.9739, Test : 0.9344
# [EPOCH] : [51] 모델을 저장합니다.
# [Loss : 51/100] Train : 0.0748, Test : 0.1862
# [Score  : 51/100] Train : 0.9744, Test : 0.9344
# [EPOCH] : [52] 모델을 저장합니다.
# [Loss : 52/100] Train : 0.0739, Test : 0.1848
# [Score  : 52/100] Train : 0.9747, Test : 0.9350
# [EPOCH] : [53] 모델을 저장합니다.
# [Loss : 53/100] Train : 0.0731, Test : 0.1834
# [Score  : 53/100] Train : 0.9750, Test : 0.9359
# [EPOCH] : [54] 모델을 저장합니다.
# [Loss : 54/100] Train : 0.0723, Test : 0.1821
# [Score  : 54/100] Train : 0.9754, Test : 0.9362
# [EPOCH] : [55] 모델을 저장합니다.
# [Loss : 55/100] Train : 0.0716, Test : 0.1809
# [Score  : 55/100] Train : 0.9758, Test : 0.9357
# [EPOCH] : [56] 모델을 저장합니다.
# [Loss : 56/100] Train : 0.0708, Test : 0.1798
# [Score  : 56/100] Train : 0.9762, Test : 0.9368
# [EPOCH] : [57] 모델을 저장합니다.
# [Loss : 57/100] Train : 0.0701, Test : 0.1786
# [Score  : 57/100] Train : 0.9765, Test : 0.9371
# [EPOCH] : [58] 모델을 저장합니다.
# [Loss : 58/100] Train : 0.0693, Test : 0.1776
# [Score  : 58/100] Train : 0.9767, Test : 0.9378
# [EPOCH] : [59] 모델을 저장합니다.
# [Loss : 59/100] Train : 0.0686, Test : 0.1766
# [Score  : 59/100] Train : 0.9771, Test : 0.9381
# [EPOCH] : [60] 모델을 저장합니다.
# [Loss : 60/100] Train : 0.0679, Test : 0.1757
# [Score  : 60/100] Train : 0.9772, Test : 0.9384
# [EPOCH] : [61] 모델을 저장합니다.
# [Loss : 61/100] Train : 0.0672, Test : 0.1748
# [Score  : 61/100] Train : 0.9776, Test : 0.9375
# [EPOCH] : [62] 모델을 저장합니다.
# [Loss : 62/100] Train : 0.0666, Test : 0.1740
# [Score  : 62/100] Train : 0.9779, Test : 0.9376
# [EPOCH] : [63] 모델을 저장합니다.
# [Loss : 63/100] Train : 0.0659, Test : 0.1732
# [Score  : 63/100] Train : 0.9782, Test : 0.9387
# [EPOCH] : [64] 모델을 저장합니다.
# [Loss : 64/100] Train : 0.0653, Test : 0.1725
# [Score  : 64/100] Train : 0.9784, Test : 0.9394
# [EPOCH] : [65] 모델을 저장합니다.
# [Loss : 65/100] Train : 0.0647, Test : 0.1719
# [Score  : 65/100] Train : 0.9788, Test : 0.9394
# [EPOCH] : [66] 모델을 저장합니다.
# [Loss : 66/100] Train : 0.0641, Test : 0.1712
# [Score  : 66/100] Train : 0.9791, Test : 0.9399
# [EPOCH] : [67] 모델을 저장합니다.
# [Loss : 67/100] Train : 0.0635, Test : 0.1707
# [Score  : 67/100] Train : 0.9795, Test : 0.9402
# [EPOCH] : [68] 모델을 저장합니다.
# [Loss : 68/100] Train : 0.0629, Test : 0.1701
# [Score  : 68/100] Train : 0.9797, Test : 0.9409
# [EPOCH] : [69] 모델을 저장합니다.
# [Loss : 69/100] Train : 0.0623, Test : 0.1696
# [Score  : 69/100] Train : 0.9799, Test : 0.9414
# [EPOCH] : [70] 모델을 저장합니다.
# [Loss : 70/100] Train : 0.0617, Test : 0.1692
# [Score  : 70/100] Train : 0.9801, Test : 0.9412
# [EPOCH] : [71] 모델을 저장합니다.
# [Loss : 71/100] Train : 0.0612, Test : 0.1688
# [Score  : 71/100] Train : 0.9804, Test : 0.9412
# [EPOCH] : [72] 모델을 저장합니다.
# [Loss : 72/100] Train : 0.0606, Test : 0.1684
# [Score  : 72/100] Train : 0.9806, Test : 0.9415
# [EPOCH] : [73] 모델을 저장합니다.
# [Loss : 73/100] Train : 0.0601, Test : 0.1681
# [Score  : 73/100] Train : 0.9807, Test : 0.9421
# [EPOCH] : [74] 모델을 저장합니다.
# [Loss : 74/100] Train : 0.0596, Test : 0.1678
# [Score  : 74/100] Train : 0.9808, Test : 0.9424
# [EPOCH] : [75] 모델을 저장합니다.
# [Loss : 75/100] Train : 0.0590, Test : 0.1675
# [Score  : 75/100] Train : 0.9809, Test : 0.9424
# [EPOCH] : [76] 모델을 저장합니다.
# [Loss : 76/100] Train : 0.0585, Test : 0.1673
# [Score  : 76/100] Train : 0.9810, Test : 0.9427
# [EPOCH] : [77] 모델을 저장합니다.
# [Loss : 77/100] Train : 0.0580, Test : 0.1671
# [Score  : 77/100] Train : 0.9812, Test : 0.9430
# [EPOCH] : [78] 모델을 저장합니다.
# [Loss : 78/100] Train : 0.0575, Test : 0.1669
# [Score  : 78/100] Train : 0.9813, Test : 0.9427
# [EPOCH] : [79] 모델을 저장합니다.
# [Loss : 79/100] Train : 0.0571, Test : 0.1668
# [Score  : 79/100] Train : 0.9815, Test : 0.9423
# [EPOCH] : [80] 모델을 저장합니다.
# [Loss : 80/100] Train : 0.0566, Test : 0.1667
# [Score  : 80/100] Train : 0.9816, Test : 0.9424
# [EPOCH] : [81] 모델을 저장합니다.
# [Loss : 81/100] Train : 0.0561, Test : 0.1666
# [Score  : 81/100] Train : 0.9818, Test : 0.9420
# [EPOCH] : [82] 모델을 저장합니다.
# [Loss : 82/100] Train : 0.0557, Test : 0.1666
# [Score  : 82/100] Train : 0.9820, Test : 0.9420
# [Loss : 83/100] Train : 0.0552, Test : 0.1666
# [Score  : 83/100] Train : 0.9822, Test : 0.9417
# [Loss : 84/100] Train : 0.0548, Test : 0.1667
# [Score  : 84/100] Train : 0.9824, Test : 0.9415
# [Loss : 85/100] Train : 0.0544, Test : 0.1667
# [Score  : 85/100] Train : 0.9826, Test : 0.9414
# [Loss : 86/100] Train : 0.0540, Test : 0.1669
# [Score  : 86/100] Train : 0.9827, Test : 0.9417
# [Loss] 값의 개선이 이루어지지 않아 [87] EPOCH에서 학습을 종료합니다.

# %%
DrawPlot(result)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
MODEL_PATH=r'C:\WorkSpace\LocalData\pj_14_final\res_model\best_model_epoch_82.pth'

# %%
best_model = models.resnet50(weights=ResNet50_Weights.IMAGENET1K_V1).to(device)

best_model.fc = nn.Linear(best_model.fc.in_features, 4)

best_model.load_state_dict(torch.load(MODEL_PATH, weights_only=True, map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
input_data = []
target_data = []
for i, j in validDL:
    input_data.append(i)
    target_data.append(j)
    break

# %%
input_data[0].shape
# Out:
# torch.Size([32, 3, 224, 224])

# %%
pred_value = torch.argmax(best_model(input_data[0]), dim=1)
pred_value
# Out:
# tensor([1, 0, 0, 2, 3, 0, 2, 3, 2, 2, 1, 3, 3, 2, 3, 2, 1, 1, 3, 3, 0, 2, 0, 3,
#         1, 0, 3, 2, 2, 1, 0, 3])

# %%
{i : DS.classes[i] for i in range(len(DS.classes))}
# Out:
# {0: 'fire', 1: 'nofire', 2: 'smoke', 3: 'smokefire'}

# %%
INDEX = 5 # 배치 사이즈 범위 내의 값

name_dict = {i : DS.classes[i] for i in range(len(DS.classes))}
pred_name = name_dict[pred_value[INDEX].item()]
real_name = name_dict[target_data[0][INDEX].item()]
plt.imshow(input_data[0][INDEX].permute(1,2,0))
plt.title(f'[실제] : {real_name}\n[예측] : {pred_name}')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_target=[i[0] for i in testDL.dataset]
test_label=[i[1] for i in testDL.dataset]
